# %% [markdown]
# Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Flask is a web framework that allows developers to build lightweight web applications quickly and easily with Flask Libraries. It was developed by Armin Ronacher.

# %% [markdown]
# Advantages of flask:-

# %% [markdown]
# 1.)Flask is a lightweight backend framework with minimal dependencies.
# 2.)Flask is easy to learn because its simple and intuitive API makes it easy to learn and use for beginners.
# 3.)Flask is a flexible Framework because it allows you to customize and extend the framework to suit your needs easily.

# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# ![Ss_ruunning_flask.png](attachment:2dea9aca-23b7-408b-9908-cc3144f96ec3.png)

# %% [markdown]
# ![ss_flask_assignment1.png](attachment:ac0c4ca6-d7d7-4113-99bc-dbda342d2af9.png)

# %% [markdown]
# ![ss_flask_assignment1.png](attachment:ac0c4ca6-d7d7-4113-99bc-dbda342d2af9.png)

# %% [markdown]
# ![Ss_ruunning_flask.png](attachment:2dea9aca-23b7-408b-9908-cc3144f96ec3.png)

# %% [markdown]
# Q3. What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# App routing is the technique used to map the specific URL with the associated function intended to perform some task. The Latest Web frameworks use the routing technique to help users remember application URLs.

# %% [markdown]
# To bind a function to an URL path we use the app.route decorator. In the above example, I have implemented the app routing in the flask.

# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %% [markdown]
# ![Abc_py_ss.png](attachment:d7190d0c-b317-4548-96f3-4897827208a7.png)

# %% [markdown]
# ![Abc_py_ss.png](attachment:d7190d0c-b317-4548-96f3-4897827208a7.png)

# %% [markdown]
# ![Abc_output_ss.png](attachment:06d7b7f9-392d-432e-baa9-35ecf13ae2ae.png)

# %% [markdown]
# ![Abc_output_ss.png](attachment:06d7b7f9-392d-432e-baa9-35ecf13ae2ae.png)

# %% [markdown]
# ![Screenshot 2023-06-18 230350.png](attachment:ef585a02-4cea-4a74-afea-2d0bb7b6de78.png)

# %% [markdown]
# Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.

# %% [markdown]
# The url_for() function is used to build a URL to the specific function dynamically. The first argument is the name of the specified function, and then we can pass any number of keyword argument corresponding to the variable part of the URL.

# %% [markdown]
# Python code to demonstrate the working of the url_for() function:-

# %%
from flask import url_for, Flask

appFlask = Flask(__name__)

@appFlask.route('/home')
def home():
   return 'We are in Home Page!'
with appFlask.test_request_context():
    print(url_for('login'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from flask import url_for, Flask
#       3 appFlask = Flask(__name__)
#       5 @appFlask.route('/home')
#       6 def home():
#
# ModuleNotFoundError: No module named 'flask'
